# %%
import os
import sys
import glob
from os import write

from tqdm import tqdm
import pandas as pd
import numpy as np
import ast

sys.path.append(os.path.realpath(os.path.abspath('..')))
from iDrink import iDrinkUtilities

# %%
drive = iDrinkUtilities.get_drivepath()

root_iDrink = os.path.join(drive, 'iDrink')
root_val = os.path.join(root_iDrink, "validation_root")
root_stat = os.path.join(root_val, '04_Statistics')
root_omc = os.path.join(root_val, '03_data', 'OMC_new', 'S15133')
root_data = os.path.join(root_val, "03_data")
root_logs = os.path.join(root_val, "05_logs")

csv_val_trials = os.path.join(root_logs, 'validation_trials.csv')
df_val_trials = pd.read_csv(csv_val_trials, sep=';')

csv_settings = os.path.join(root_logs, 'validation_settings.csv')
df_settings = pd.read_csv(csv_settings, sep=';')

csv_calib_error = os.path.join(root_logs, 'calib_errors.csv')
df_calib_error = pd.read_csv(csv_calib_error, sep=';')

csv_murphy = os.path.join(root_stat, '02_categorical', 'murphy_measures.csv')
df_murphy = pd.read_csv(csv_murphy, sep=';')

csv_failed_trials = os.path.join(root_stat, '04_failed_trials', 'failed_trials.csv')
df_failed_trials = pd.read_csv(csv_failed_trials, sep=';')

list_identifier = sorted(df_val_trials['identifier'].tolist())

# %% [markdown]
# # Range of Motion Error
# ## Time-Series

# %%
dir_stat_cont = os.path.join(root_stat, '01_continuous')

dir_results = os.path.join(dir_stat_cont, '01_results')
dir_plots = os.path.join(dir_stat_cont, '02_plots')

csv_rom = os.path.join(dir_results, 'omc_mmc_rom.csv')
csv_rom_rmse = os.path.join(dir_results, 'omc_mmc_rom_rmse.csv')

df_rom = pd.read_csv(csv_rom, sep=';')
df_rom_rmse = pd.read_csv(csv_rom_rmse, sep=';')

# %%
metrics = ['hand_vel', 'elbow_vel', 'trunk_disp', 'trunk_ang', 'elbow_flex_pos', 'shoulder_flex_pos', 'shoulder_abduction_pos']

# %%
df_rom.dropna(axis=1, inplace=True)

# %%
df_rom
# Out:
#        id_s id_p  id_t   condition  dynamic  hand_vel_min_omc  \
# 0      S001  P07  T002  unaffected    fixed          5.401663
# 1      S001  P07  T003  unaffected    fixed          6.577809
# 2      S001  P07  T004  unaffected    fixed          5.662565
# 3      S001  P07  T005  unaffected    fixed          5.029393
# 4      S001  P07  T006  unaffected    fixed          8.624280
# ...     ...  ...   ...         ...      ...               ...
# 18267  S026  P19  T089    affected  dynamic         19.401240
# 18268  S026  P19  T090    affected  dynamic         10.269883
# 18269  S026  P19  T091    affected  dynamic         29.203020
# 18270  S026  P19  T093    affected  dynamic         34.074259
# 18271  S026  P19  T094    affected  dynamic          7.917607
#
#        elbow_vel_min_omc  trunk_disp_min_omc  trunk_ang_min_omc  \
# 0               0.008057            0.021792         239.425121
# 1               0.004029            0.183685         238.268373
# 2               0.002864            0.250142         238.873118
# 3               0.001138            0.190267         238.794405
# 4               0.003736            0.168062         237.856457
# ...                  ...                 ...                ...
# 18267           0.027651            0.054317         225.024458
# 18268           0.016205            3.674978         225.091297
# 18269           0.007325            0.079272         226.017044
# 18270           0.017776            0.098772         224.651876
# 18271           0.006902            0.320117         227.248801
#
#        elbow_flex_pos_min_omc  ...  elbow_flex_pos_rom_mmc  \
# 0                   25.229077  ...              106.796244
# 1                   29.756802  ...              101.836116
# 2                   28.820865  ...              101.379589
# 3                   27.462963  ...              103.469637
# 4                   29.466485  ...              101.473657
# ...                       ...  ...                     ...
# 18267               91.164692  ...               60.168993
# 18268               87.422893  ...               65.806061
# 18269               80.815563  ...               68.016375
# 18270               93.009152  ...               59.012221
# 18271               94.882673  ...               59.039904
#
#        shoulder_flex_pos_rom_mmc  shoulder_abduction_pos_rom_mmc  \
# 0                      48.941794                       22.919996
# 1                      46.281159                       18.800373
# 2                      44.287363                       20.597249
# 3                      43.129052                       17.456085
# 4                      44.883091                       18.221546
# ...                          ...                             ...
# 18267                  46.366571                       15.353380
# 18268                  43.048348                       41.381757
# 18269                  48.620229                       22.189512
# 18270                  33.535559                       10.411223
# 18271                  50.832560                       14.886292
#
#        hand_vel_rom_error  elbow_vel_rom_error  trunk_disp_rom_error  \
# 0               78.914598             1.283200             -1.226687
# 1               49.680249             1.023726             -5.195442
# 2               76.310767             1.036164             -1.367575
# 3             -438.027110             1.173248             -3.949034
# 4                1.816262             1.077599             -1.447764
# ...                   ...                  ...                   ...
# 18267          710.689798             1.256005             31.826237
# 18268          415.176212             0.867440            105.904876
# 18269          802.157132             1.287449             53.036796
# 18270          478.462753             1.376523             12.673307
# 18271          314.079157             1.212447             14.858096
#
#        trunk_ang_rom_error  elbow_flex_pos_rom_error  \
# 0                 8.068424                  0.836467
# 1                 6.354541                 -2.170690
# 2                 6.417420                 -0.443602
# 3                 6.263201                 -0.529130
# 4                 7.138701                  0.417477
# ...                    ...                       ...
# 18267            -2.820632                 17.233541
# 18268             7.916608                 21.256582
# 18269             3.740413                 15.081466
# 18270             1.173781                 19.897492
# 18271            -0.661421                 18.368084
#
#        shoulder_flex_pos_rom_error  shoulder_abduction_pos_rom_error
# 0                         1.898610                         -1.977024
# 1                        -0.673879                         -1.332835
# 2                         2.735974                         -1.308428
# 3                        -0.710135                         -2.642826
# 4                         2.999048                         -2.215235
# ...                            ...                               ...
# 18267                    -5.173885                         -4.023573
# 18268                   -16.905804                         10.467419
# 18269                    -7.487340                          1.233467
# 18270                    -9.561449                         -1.559122
# 18271                    -3.590008                          0.406548
#
# [18272 rows x 54 columns]
